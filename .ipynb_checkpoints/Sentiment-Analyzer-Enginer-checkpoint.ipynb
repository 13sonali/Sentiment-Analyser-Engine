# %%
import tweepy, re
from textblob import TextBlob
import matplotlib.pyplot as plt
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
#authentication
consumerKey = 'Javavx8YLf0TLDcsSQZlnPMN5'
consumerSecret = 'vzzeLqEJx2sGSyZu2UnH4T7w4MPYH6yxRLfGI5WQXdPjfRY5R6'
accessToken = '1316978914544164869-eLoidJJgknQSPcmGlfSCYwM3jJwCJ7'
accessTokenSecret ='rRCNvNHPQfGtgdsGbA0dDNkeXhUoULHk3P76Adi7tR1kt'
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
#input for term to be searched and how many tweets to search
searchTerm = input("Enter Keyword/Tag to search about: ")
NoOfTerms = int(input("Enter how many tweets to be searched: "))

tweets = []
tweetText = []

#searching for tweets
tweets = tweepy.Cursor(api.search, q=searchTerm+" -filter:retweets", lang = 'en').items(NoOfTerms)
# Out:
# Enter Keyword/Tag to search about: Virat Kohli
# Enter how many tweets to be searched: 50

# %%
tweet_list = [tweet.text for tweet in tweets]
tweet_df = pd.DataFrame(tweet_list)
tweet_df
# Out:
#                                                     0
# 0   Virat Kohli has hit the most sixes in death ov...
# 1   12 cricketers have scored 20k+ int'l runs whil...
# 2   Virat Kohli has the Most Man of the Match Awar...
# 3   @NottsGirljess Yes , like England team in intl...
# 4   Virat Kohli during the net practice!\n\n📸 : @B...
# 5   ENG vs IND: Virat Kohli And India Teammates Al...
# 6   Virat Kohli is the only captain in history of ...
# 7   @muhammadkaif158 my best t20 11 \n1. ROHIT SHA...
# 8   "He is right up with those guys" #INDvSL\n\nht...
# 9   @sayantansunnyg Why people in India talk more ...
# 10  In T20Is, he is no less than Virat Kohli, Rish...
# 11  "My favourite Indian Batsman is Virat Kohli, R...
# 12  Virat Kohli and the players in the Gym workout...
# 13  Beautiful girl just landed in our nearby flats...
# 14  That's the impact of Virat Kohli on youngsters...
# 15  @Kami4567891 @Rish9131 @baqicricketer Truly Th...
# 16  Steve Smith can have better test avg\nDhoni ca...
# 17  Wasim Jaffer trolled Barmy Army for taking a d...
# 18  @Imma_Sledge3 Was he following Virat Kohli on ...
# 19  #Cricket #CricketNews Wasim Jaffer comes up wi...
# 20  Don't know why, but match without Rohit Sharma...
# 21  • Virat Kohli in Just won matches Scored 14,82...
# 22  Virat Kohli is the only captain to score 10 or...
# 23  @Vaibhav23584780 @imVkohli very thoughtful of ...
# 24  82 cricketers have scored 10k int'l runs while...
# 25  𝗛𝗶𝗴𝗵𝗲𝘀𝘁 𝗯𝗮𝘁𝘁𝗶𝗻𝗴 𝗮𝘃𝗲𝗿𝗮𝗴𝗲𝘀 𝘃𝘀. 𝘀𝗽𝗶𝗻 for current ...
# 26  @ABDxSRK ofc our most of mutuals are of Kohli ...
# 27  Virat Kohli is the only captain to score 10 or...
# 28  Virat Kohli Shares Post Workout Picture as Tea...
# 29  @Vishuu_18 Except Virat Kohli (3 formats) bett...
# 30  @virat_holics More in Kohli FC as far as I've ...
# 31  @TLadnam Well I definitely agree with you....T...
# 32  ENG vs IND: Virat Kohli And India Teammates Al...
# 33  Virat Kohli is the only captain to score 10 or...
# 34  @ABDxSRK This is not just about kohli FC such ...
# 35  Some of worst comparison\n\nSachin better than...
# 36  @FarziCricketer virat kohli se speech dilwa do...
# 37  As we speak some woke guy will criticize crick...
# 38  I can Bet Babar Can never score with this cons...
# 39  @Vaibhav23584780 @imVkohli And you don't have ...
# 40  Virat Kohli Shares Post Workout Picture as Tea...
# 41  @Phoenix9904 @dankythamizhan @RushikeshHalda4 ...
# 42  @imVkohli Dear Virat Kohli, \nOne tweet for @m...
# 43  @imVkohli watch this who loves Virat kohli\nht...
# 44  @imVkohli All those people who are comparing "...
# 45  @tanish_vk_18 I am also fan of virat kohli . B...
# 46  Virat Kohli, Rishabh Pant, Rohit Sharma in the...
# 47  @Liam628 Don't know how Virat Kohli must be fe...
# 48  England vs India: Virat Kohli and all India te...
# 49  ENG vs IND: Virat Kohli And India Teammates Al...

# %%
def clean_data(text):
    return ' '.join(re.sub("(@[a-zA-Z0-9]+)|([^0-9A-Za-z])|(https://[\w.]+/[\w]+)", " ", text).split())

tweet_df['cleaned_data'] = tweet_df[0].apply(clean_data)

# %%
tweet_df.head()
# Out:
#                                                    0
# 0  Virat Kohli has hit the most sixes in death ov...
# 1  12 cricketers have scored 20k+ int'l runs whil...
# 2  Virat Kohli has the Most Man of the Match Awar...
# 3  @NottsGirljess Yes , like England team in intl...
# 4  Virat Kohli during the net practice!\n\n📸 : @B...

# %%
def drop_numbers(list_text):
    list_text_new = []
    for i in list_text:
        if not re.search('\d', i):
            list_text_new.append(i)
    return ''.join(list_text_new)

tweet_df['cleaned_data'] = tweet_df['cleaned_data'].apply(drop_numbers)

# %%
tweet_df.head()
# Out:
#                                                    0
# 0  Virat Kohli has hit the most sixes in death ov...
# 1  12 cricketers have scored 20k+ int'l runs whil...
# 2  Virat Kohli has the Most Man of the Match Awar...
# 3  @NottsGirljess Yes , like England team in intl...
# 4  Virat Kohli during the net practice!\n\n📸 : @B...

# %%
# changing all the words of the reviews column to lowercase letters
def lower_case(text):
    text_words = word_tokenize(text)
    text_words_lower = [x.lower() for x in text_words]
    return ' '.join(text_words_lower)

tweet_df['cleaned_data'] = tweet_df['cleaned_data'].apply(lower_case)
